# %%
# Name: Sai Anish Garapati
# UIN: 650208577

# %% [markdown]
# ## Importing required Libraries

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import os
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as image
from PIL import Image

# %% [markdown]
# ## Custom Dataset Class

# %%
class TrafficImageDatset(Dataset):
	def __init__(self, csv_file, root_dir, transform=None):
		self.csv_content = pd.read_csv(csv_file, usecols=['ClassId', 'Path'])
		self.root_dir = root_dir
		self.transform = transform

	def __len__(self):
		return len(self.csv_content)
	
	def __getitem__(self, index):
		img = Image.open(self.root_dir + self.csv_content.iloc[index, 1])
		label = torch.tensor(int(self.csv_content.iloc[index, 0]))

		if self.transform:
			img_tensor = self.transform(img)
		
		return (img_tensor, label)

# %% [markdown]
# ## Neural Network Model (CNN)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(1024, 512)
        self.fc2 = nn.Linear(512, 128)
        self.fc3 = nn.Linear(128, 43)

    def forward(self, x):
        x = torch.flatten(x, 1)
        x = F.relu(self.fc1(x))
        x = self.dropout2(x)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ## Training Function

# %%
def train_model(device, model, train_loader, optimizer, epoch, batch_size):
    model.train()
    tot_loss = 0
    correct = 0
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = torch.nn.CrossEntropyLoss()(output, label)
        loss.backward()
        optimizer.step()

        predictions = output.argmax(dim=1, keepdim=True)
        correct += predictions.eq(label.view_as(predictions)).sum().item()
        tot_loss += loss.item()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}, Accuracy: {:.2f}%'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100.0 * batch_idx /
                len(train_loader), tot_loss / (batch_idx + 1),
                100.0 * correct / ((batch_idx + 1) * batch_size)))
    print('End of Epoch: {}'.format(epoch))
    print('Training Loss: {:.6f}, Training Accuracy: {:.2f}%'.format(
        tot_loss / len(train_loader), 100.0 * correct / (len(train_loader) * batch_size)))

    return tot_loss / len(train_loader), 100.0 * correct / (len(train_loader) * batch_size)

# %% [markdown]
# ## Validation Function

# %%
def validation_model(device, model, validation_loader, batch_size):
    model.eval()
    tot_loss = 0
    correct = 0
    with torch.no_grad():
        for batch_idx, (data, label) in enumerate(validation_loader):
            data, label = data.to(device), label.to(device)
            output = model(data)
            tot_loss += torch.nn.CrossEntropyLoss()(output, label).item()
            predictions = output.argmax(dim=1, keepdim=True)
            correct += predictions.eq(label.view_as(predictions)).sum().item()


    print('Validation Loss: {:.6f}, Validation Accuracy: {:.2f}%'.format(
        tot_loss / len(validation_loader),
        100.0 * correct / (len(validation_loader) * batch_size)
    ))

    return tot_loss/len(validation_loader), 100.0 * correct / (len(validation_loader) * batch_size)

# %%
def test_model(device, model, test_loader, batch_size):
    model.eval()
    tot_loss = 0
    correct = 0
    with torch.no_grad():
        for batch_idx, (data, label) in enumerate(test_loader):
            data, label = data.to(device), label.to(device)
            output = model(data)
            tot_loss += torch.nn.CrossEntropyLoss()(output, label).item()
            predictions = output.argmax(dim=1, keepdim=True)
            correct += predictions.eq(label.view_as(predictions)).sum().item()

    print('Test Loss: {:.6f}, Test Accuracy: {:.2f}%'.format(
        tot_loss / len(test_loader),
        100.0 * correct / (len(test_loader) * batch_size)
    ))

    return tot_loss/len(test_loader), 100.0 * correct / (len(test_loader) * batch_size)

# %% [markdown]
# ## Loading Dataset using Dataloader and preprocessing

# %%
torch.manual_seed(2021)
root_path = '../../../../ML_Project_Data/'
train_batch_size = 256
validation_batch_size = 500
test_batch_size = 1
learning_rate = 0.01

transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.1),
    transforms.RandomAutocontrast(p=0.4),
    transforms.Resize(32),
    transforms.RandomCrop(32),
    transforms.Grayscale(),
    transforms.ToTensor(),
])

train_dataset = TrafficImageDatset(csv_file=root_path + 'Train.csv', root_dir = root_path, transform=transform)
test_dataset = TrafficImageDatset(csv_file=root_path + 'Test.csv', root_dir=root_path, transform=transform)

training_length = int(0.90 * len(train_dataset))
validation_length = len(train_dataset) - training_length

train_set, validation_set = torch.utils.data.random_split(train_dataset, [training_length, validation_length])

train_loader = DataLoader(dataset=train_set, batch_size=train_batch_size, shuffle=True)
validation_loader = DataLoader(dataset=validation_set, batch_size=validation_batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=test_batch_size, shuffle=False)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

model = Net().to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = StepLR(optimizer, step_size=10, gamma=0.8)

training_loss = []
training_accuracy = []
validation_loss = []
validation_accuracy = []
test_loss = []
test_accuracy = []

for epoch in range(0, 25):
    loss, accuracy = train_model(device, model, train_loader, optimizer, epoch + 1, train_batch_size)
    training_loss.append(loss)
    training_accuracy.append(accuracy)

    loss, accuracy = validation_model(device, model, validation_loader, validation_batch_size)
    validation_loss.append(loss)
    validation_accuracy.append(accuracy)

    loss, accuracy = test_model(device, model, test_loader, test_batch_size)
    test_loss.append(loss)
    test_accuracy.append(accuracy)

    scheduler.step()


# %matplotlib inline
plt.title('Plot of Epochs vs Loss for training and validation data')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.plot(list(range(1, len(training_loss) + 1)), training_loss, 'r', label='Training set')
plt.plot(list(range(1, len(validation_loss) + 1)), validation_loss, 'b', label='validation set')
plt.legend(title='Legend')
plt.show()

plt.title('Plot of Epochs vs Accuracy for training and validation data')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(list(range(1, len(training_loss) + 1)), training_accuracy, 'r', label='Training set')
plt.plot(list(range(1, len(validation_loss) + 1)), validation_accuracy, 'b', label='validation set')
plt.legend(title='Legend')
plt.show()

torch.save(model.state_dict(), 'ML_Model.pt')
# Out:
# Train Epoch: 1 [0/35288 (0%)]	Loss: 3.746832, Accuracy: 1.56%
# Train Epoch: 1 [12800/35288 (36%)]	Loss: 3.352578, Accuracy: 12.06%
# Train Epoch: 1 [25600/35288 (72%)]	Loss: 3.024045, Accuracy: 20.03%
# End of Epoch: 1
# Training Loss: 2.797357, Training Accuracy: 25.31%
# Validation Loss: 1.901532, Validation Accuracy: 45.73%
# Test Loss: 2.089905, Test Accuracy: 41.61%
# Train Epoch: 2 [0/35288 (0%)]	Loss: 1.980160, Accuracy: 42.97%
# Train Epoch: 2 [12800/35288 (36%)]	Loss: 1.933715, Accuracy: 45.97%
# Train Epoch: 2 [25600/35288 (72%)]	Loss: 1.835393, Accuracy: 48.80%
# End of Epoch: 2
# Training Loss: 1.769316, Training Accuracy: 50.70%
# Validation Loss: 1.387030, Validation Accuracy: 61.67%
# Test Loss: 1.661979, Test Accuracy: 55.19%
# Train Epoch: 3 [0/35288 (0%)]	Loss: 1.401177, Accuracy: 63.28%
# Train Epoch: 3 [12800/35288 (36%)]	Loss: 1.496517, Accuracy: 58.03%
# Train Epoch: 3 [25600/35288 (72%)]	Loss: 1.459889, Accuracy: 59.38%
# End of Epoch: 3
# Training Loss: 1.437554, Training Accuracy: 59.82%
# Validation Loss: 1.190493, Validation Accuracy: 66.05%
# Test Loss: 1.537358, Test Accuracy: 59.74%
# Train Epoch: 4 [0/35288 (0%)]	Loss: 1.239815, Accuracy: 67.19%
# Train Epoch: 4 [12800/35288 (36%)]	Loss: 1.292447, Accuracy: 64.16%
# Train Epoch: 4 [25600/35288 (72%)]	Loss: 1.251724, Accuracy: 65.04%
# End of Epoch: 4
# Training Loss: 1.242610, Training Accuracy: 65.36%
# Validation Loss: 1.006328, Validation Accuracy: 72.08%
# Test Loss: 1.333945, Test Accuracy: 65.24%
# Train Epoch: 5 [0/35288 (0%)]	Loss: 1.087159, Accuracy: 65.62%
# Train Epoch: 5 [12800/35288 (36%)]	Loss: 1.173052, Accuracy: 67.22%
# Train Epoch: 5 [25600/35288 (72%)]	Loss: 1.150577, Accuracy: 67.55%
# End of Epoch: 5
# Training Loss: 1.137858, Training Accuracy: 67.97%
# Validation Loss: 0.841248, Validation Accuracy: 76.53%
# Test Loss: 1.227767, Test Accuracy: 69.68%
# Train Epoch: 6 [0/35288 (0%)]	Loss: 0.991516, Accuracy: 66.41%
# Train Epoch: 6 [12800/35288 (36%)]	Loss: 1.042152, Accuracy: 70.15%
# Train Epoch: 6 [25600/35288 (72%)]	Loss: 1.039123, Accuracy: 70.48%
# End of Epoch: 6
# Training Loss: 1.028667, Training Accuracy: 70.75%
# Validation Loss: 0.794886, Validation Accuracy: 77.60%
# Test Loss: 1.212008, Test Accuracy: 70.95%
# Train Epoch: 7 [0/35288 (0%)]	Loss: 1.068502, Accuracy: 73.44%
# Train Epoch: 7 [12800/35288 (36%)]	Loss: 0.968980, Accuracy: 72.50%
# Train Epoch: 7 [25600/35288 (72%)]	Loss: 0.967940, Accuracy: 72.67%
# End of Epoch: 7
# Training Loss: 0.966568, Training Accuracy: 72.48%
# Validation Loss: 0.732059, Validation Accuracy: 80.05%
# Test Loss: 1.140679, Test Accuracy: 72.52%
# Train Epoch: 8 [0/35288 (0%)]	Loss: 0.995110, Accuracy: 73.44%
# Train Epoch: 8 [12800/35288 (36%)]	Loss: 0.934466, Accuracy: 73.54%
# Train Epoch: 8 [25600/35288 (72%)]	Loss: 0.920774, Accuracy: 73.71%
# End of Epoch: 8
# Training Loss: 0.921797, Training Accuracy: 73.66%
# Validation Loss: 0.697140, Validation Accuracy: 79.97%
# Test Loss: 1.142805, Test Accuracy: 73.08%
# Train Epoch: 9 [0/35288 (0%)]	Loss: 0.716336, Accuracy: 82.81%
# Train Epoch: 9 [12800/35288 (36%)]	Loss: 0.884981, Accuracy: 75.28%
# Train Epoch: 9 [25600/35288 (72%)]	Loss: 0.890368, Accuracy: 74.91%
# End of Epoch: 9
# Training Loss: 0.878913, Training Accuracy: 75.03%
# Validation Loss: 0.656958, Validation Accuracy: 79.55%
# Test Loss: 1.090704, Test Accuracy: 73.32%
# Train Epoch: 10 [0/35288 (0%)]	Loss: 0.699879, Accuracy: 78.12%
# Train Epoch: 10 [12800/35288 (36%)]	Loss: 0.869142, Accuracy: 75.36%
# Train Epoch: 10 [25600/35288 (72%)]	Loss: 0.844271, Accuracy: 76.31%
# End of Epoch: 10
# Training Loss: 0.839524, Training Accuracy: 76.27%
# Validation Loss: 0.613565, Validation Accuracy: 82.00%
# Test Loss: 1.039159, Test Accuracy: 75.64%
# Train Epoch: 11 [0/35288 (0%)]	Loss: 0.662343, Accuracy: 78.12%
# Train Epoch: 11 [12800/35288 (36%)]	Loss: 0.786194, Accuracy: 77.61%
# Train Epoch: 11 [25600/35288 (72%)]	Loss: 0.772182, Accuracy: 78.12%
# End of Epoch: 11
# Training Loss: 0.771369, Training Accuracy: 77.96%
# Validation Loss: 0.535686, Validation Accuracy: 84.05%
# Test Loss: 1.012680, Test Accuracy: 77.37%
# Train Epoch: 12 [0/35288 (0%)]	Loss: 0.897390, Accuracy: 79.69%
# Train Epoch: 12 [12800/35288 (36%)]	Loss: 0.722270, Accuracy: 79.22%
# Train Epoch: 12 [25600/35288 (72%)]	Loss: 0.727228, Accuracy: 79.11%
# End of Epoch: 12
# Training Loss: 0.728003, Training Accuracy: 79.04%
# Validation Loss: 0.551880, Validation Accuracy: 84.25%
# Test Loss: 1.018486, Test Accuracy: 77.17%
# Train Epoch: 13 [0/35288 (0%)]	Loss: 0.630669, Accuracy: 85.94%
# Train Epoch: 13 [12800/35288 (36%)]	Loss: 0.707106, Accuracy: 79.50%
# Train Epoch: 13 [25600/35288 (72%)]	Loss: 0.711114, Accuracy: 79.49%
# End of Epoch: 13
# Training Loss: 0.711702, Training Accuracy: 79.38%
# Validation Loss: 0.546955, Validation Accuracy: 84.33%
# Test Loss: 0.993603, Test Accuracy: 77.24%
# Train Epoch: 14 [0/35288 (0%)]	Loss: 0.668956, Accuracy: 82.81%
# Train Epoch: 14 [12800/35288 (36%)]	Loss: 0.696996, Accuracy: 80.04%
# Train Epoch: 14 [25600/35288 (72%)]	Loss: 0.689493, Accuracy: 80.34%
# End of Epoch: 14
# Training Loss: 0.685543, Training Accuracy: 80.34%
# Validation Loss: 0.499329, Validation Accuracy: 85.03%
# Test Loss: 0.982694, Test Accuracy: 77.73%
# Train Epoch: 15 [0/35288 (0%)]	Loss: 0.566897, Accuracy: 83.59%
# Train Epoch: 15 [12800/35288 (36%)]	Loss: 0.668842, Accuracy: 80.67%
# Train Epoch: 15 [25600/35288 (72%)]	Loss: 0.666330, Accuracy: 80.84%
# End of Epoch: 15
# Training Loss: 0.661050, Training Accuracy: 80.92%
# Validation Loss: 0.462915, Validation Accuracy: 85.97%
# Test Loss: 0.939255, Test Accuracy: 79.36%
# Train Epoch: 16 [0/35288 (0%)]	Loss: 0.500911, Accuracy: 87.50%
# Train Epoch: 16 [12800/35288 (36%)]	Loss: 0.655358, Accuracy: 81.03%
# Train Epoch: 16 [25600/35288 (72%)]	Loss: 0.656378, Accuracy: 81.12%
# End of Epoch: 16
# Training Loss: 0.652325, Training Accuracy: 81.18%
# Validation Loss: 0.471408, Validation Accuracy: 85.70%
# Test Loss: 0.954954, Test Accuracy: 79.38%
# Train Epoch: 17 [0/35288 (0%)]	Loss: 0.917426, Accuracy: 78.12%
# Train Epoch: 17 [12800/35288 (36%)]	Loss: 0.638784, Accuracy: 81.81%
# Train Epoch: 17 [25600/35288 (72%)]	Loss: 0.629955, Accuracy: 81.91%
# End of Epoch: 17
# Training Loss: 0.638038, Training Accuracy: 81.50%
# Validation Loss: 0.462504, Validation Accuracy: 85.50%
# Test Loss: 0.943332, Test Accuracy: 79.24%
# Train Epoch: 18 [0/35288 (0%)]	Loss: 0.491807, Accuracy: 85.94%
# Train Epoch: 18 [12800/35288 (36%)]	Loss: 0.638313, Accuracy: 81.57%
# Train Epoch: 18 [25600/35288 (72%)]	Loss: 0.628642, Accuracy: 81.92%
# End of Epoch: 18
# Training Loss: 0.631632, Training Accuracy: 81.80%
# Validation Loss: 0.447328, Validation Accuracy: 86.17%
# Test Loss: 0.919919, Test Accuracy: 79.99%
# Train Epoch: 19 [0/35288 (0%)]	Loss: 0.629389, Accuracy: 84.38%
# Train Epoch: 19 [12800/35288 (36%)]	Loss: 0.595575, Accuracy: 82.61%
# Train Epoch: 19 [25600/35288 (72%)]	Loss: 0.601599, Accuracy: 82.67%
# End of Epoch: 19
# Training Loss: 0.604160, Training Accuracy: 82.46%
# Validation Loss: 0.415857, Validation Accuracy: 87.15%
# Test Loss: 0.929669, Test Accuracy: 79.16%
# Train Epoch: 20 [0/35288 (0%)]	Loss: 0.624774, Accuracy: 82.81%
# Train Epoch: 20 [12800/35288 (36%)]	Loss: 0.586451, Accuracy: 83.29%
# Train Epoch: 20 [25600/35288 (72%)]	Loss: 0.594519, Accuracy: 82.85%
# End of Epoch: 20
# Training Loss: 0.591793, Training Accuracy: 82.84%
# Validation Loss: 0.459791, Validation Accuracy: 86.10%
# Test Loss: 1.028304, Test Accuracy: 78.25%
# Train Epoch: 21 [0/35288 (0%)]	Loss: 0.561868, Accuracy: 82.03%
# Train Epoch: 21 [12800/35288 (36%)]	Loss: 0.564256, Accuracy: 83.66%
# Train Epoch: 21 [25600/35288 (72%)]	Loss: 0.558698, Accuracy: 84.14%
# End of Epoch: 21
# Training Loss: 0.547078, Training Accuracy: 84.35%
# Validation Loss: 0.389426, Validation Accuracy: 88.38%
# Test Loss: 0.891319, Test Accuracy: 80.67%
# Train Epoch: 22 [0/35288 (0%)]	Loss: 0.571755, Accuracy: 84.38%
# Train Epoch: 22 [12800/35288 (36%)]	Loss: 0.545278, Accuracy: 84.49%
# Train Epoch: 22 [25600/35288 (72%)]	Loss: 0.549298, Accuracy: 84.33%
# End of Epoch: 22
# Training Loss: 0.543387, Training Accuracy: 84.41%
# Validation Loss: 0.365787, Validation Accuracy: 88.22%
# Test Loss: 0.889640, Test Accuracy: 81.43%
# Train Epoch: 23 [0/35288 (0%)]	Loss: 0.937074, Accuracy: 77.34%
# Train Epoch: 23 [12800/35288 (36%)]	Loss: 0.538243, Accuracy: 84.43%
# Train Epoch: 23 [25600/35288 (72%)]	Loss: 0.534181, Accuracy: 84.60%
# End of Epoch: 23
# Training Loss: 0.534936, Training Accuracy: 84.58%
# Validation Loss: 0.371039, Validation Accuracy: 88.28%
# Test Loss: 0.920285, Test Accuracy: 81.25%
# Train Epoch: 24 [0/35288 (0%)]	Loss: 0.467280, Accuracy: 87.50%
# Train Epoch: 24 [12800/35288 (36%)]	Loss: 0.537148, Accuracy: 84.58%
# Train Epoch: 24 [25600/35288 (72%)]	Loss: 0.529419, Accuracy: 85.02%
# End of Epoch: 24
# Training Loss: 0.528618, Training Accuracy: 84.91%
# Validation Loss: 0.360607, Validation Accuracy: 88.28%
# Test Loss: 0.870801, Test Accuracy: 81.32%
# Train Epoch: 25 [0/35288 (0%)]	Loss: 0.395731, Accuracy: 87.50%
# Train Epoch: 25 [12800/35288 (36%)]	Loss: 0.513258, Accuracy: 85.14%
# Train Epoch: 25 [25600/35288 (72%)]	Loss: 0.510757, Accuracy: 85.29%
# End of Epoch: 25
# Training Loss: 0.516053, Training Accuracy: 84.99%
# Validation Loss: 0.357348, Validation Accuracy: 88.92%
# Test Loss: 0.858830, Test Accuracy: 81.77%
